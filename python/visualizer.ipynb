# %% [markdown]
# # Image slicer visualizer
#
# This notebook contains interactive widgets that show how different parameters impact the generated surface.

# %%
import matplotlib.pyplot as plt

from slicer_generation import *
from surface_solns import *
from custom_slicer_helpers import *

# %%
# make widgets that displays slice + axis of rotation, etc.

# %% [markdown]
# ## Single slice
